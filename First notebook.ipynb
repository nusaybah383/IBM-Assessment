# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# # Nusaybah
# # Data scientist

# %%
#"I am interested in Data science because  I love data visualization and modeling and I want to be a gap filler in world of data analytics".

# %% [markdown]
# ### Add and print code

# %%
oranges = 4
mangoes = 5
fruit = oranges + mangoes
print(fruit)
# Out:
# 9

# %%
horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.
